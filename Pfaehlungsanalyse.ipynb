# %% [markdown]
# #### Pfahlanalyse

# %%
# connects 'Pfaehlungsanalyse.py' with this worksheet and imports 'Pfahltabelle'-object
from Pfaehlungsanalyse import Pfahltabelle

# %%
# saves an object with the csv-table 'Pfahltabelle.csv' into the variable 'Pt1'
Pt1 = Pfahltabelle(input_file='Pfahltabelle.csv')

# %%
# plots all piles with some infos
Pt1.plot(relative_force=1260, save_fig=False, annotate=True, ann_size=4, ann_min=None, markersize=5,
         ann_max=None, ann_dist=0.4, add_hist=False, save_xlsx=False, filename='Pfahlausnutzung, beschriftet')

# %%
Pt1.plot(relative_force=1260, save_fig=False, annotate=False, ann_size=4, ann_min=None, markersize=5,
         ann_max=None, ann_dist=0.4, add_hist=False, save_xlsx=False, filename='Pfahlausnutzung, qualitativ')

# %%
Pt1.plot(relative_force=1260, save_fig=False, annotate=False, ann_size=5, ann_min=0.7, markersize=10,
         ann_max=None, ann_dist=0.5, add_hist=True, save_xlsx=False, n_bins=20, filename='Pfahlausnutzung, Histogramm')
